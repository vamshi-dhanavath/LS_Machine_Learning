# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d kmader/skin-cancer-mnist-ham10000
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000
# License(s): CC-BY-NC-SA-4.0
# Downloading skin-cancer-mnist-ham10000.zip to /content
# 100% 5.20G/5.20G [04:26<00:00, 21.7MB/s]
# 100% 5.20G/5.20G [04:26<00:00, 21.0MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/skin-cancer-mnist-ham10000.zip','r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# Paths to your Excel files
train_confirm_path = '/content/KCDH2024_Training_LesionGroupings.xlsx'
train_labels_path = '/content/KCDH2024_Training_GroundTruth.xlsx'
test_labels_path = '/content/KCDH2024_Test_GroundTruth.xlsx'

# %%
# Load the Excel files
train_confirm_df = pd.read_excel(train_confirm_path)
train_labels_df = pd.read_excel(train_labels_path)
test_labels_df = pd.read_excel(test_labels_path)

# %%
# Print the first few rows of the dataframes to understand their structure
print("Training Confirm DF:")
print(train_confirm_df.head())
print("Training Labels DF:")
print(train_labels_df.head())
print("Test Labels DF:")
print(test_labels_df.head())
# Out:
# Training Confirm DF:
#           image    lesion_id            diagnosis_confirm_type
# 0  ISIC_0024306  HAM_0000550  serial imaging showing no change
# 1  ISIC_0024307  HAM_0003577  serial imaging showing no change
# 2  ISIC_0024308  HAM_0001477  serial imaging showing no change
# 3  ISIC_0024309  HAM_0000484  serial imaging showing no change
# 4  ISIC_0024310  HAM_0003350                    histopathology
# Training Labels DF:
#           image  MEL  NV  BCC  AKIEC  BKL  DF  VASC
# 0  ISIC_0024306    0   1    0      0    0   0     0
# 1  ISIC_0024307    0   1    0      0    0   0     0
# 2  ISIC_0024308    0   1    0      0    0   0     0
# 3  ISIC_0024309    0   1    0      0    0   0     0
# 4  ISIC_0024310    1   0    0      0    0   0     0
# Test Labels DF:
#           image  MEL  NV  BCC  AKIEC  BKL  DF  VASC
# 0  ISIC_0034524    0   1    0      0    0   0     0
# 1  ISIC_0034525    0   1    0      0    0   0     0
# 2  ISIC_0034526    0   0    0      0    1   0     0
# 3  ISIC_0034527    0   1    0      0    0   0     0
# 4  ISIC_0034528    0   1    0      0    0   0     0

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/KCDH2024_Test_Input.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# Define image paths
train_image_dir = '/content/HAM10000_images_part_1'
test_image_dir = '/content/KCDH2024_Test_Input'

# Image parameters
IMG_HEIGHT = 128
IMG_WIDTH = 128

def load_images(image_dir, dataframe, disease_categories):
    images = []
    labels = []
    missing_files = []
    for index, row in dataframe.iterrows():
        img_path = os.path.join(image_dir, row['image'] + '.jpg')
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
            images.append(img)
            labels.append(row[disease_categories].values.astype('float32'))
        else:
            missing_files.append(img_path)
    images = np.array(images) / 255.0
    labels = np.array(labels)
    if missing_files:
        print(f"Missing files: {missing_files}")
    return images, labels

# %%
# Disease categories
disease_categories = ['MEL', 'NV', 'BCC', 'AKIEC', 'BKL', 'DF', 'VASC']

# %%
# # Load training and test images
X_train, y_train = load_images(train_image_dir, train_labels_df, disease_categories)
000_images_part_1/ISIC_0029361.jpg', '/content/HAM10000_images_part_1/ISIC_0029362.jpg', '/content/HAM10000_images_part_1/ISIC_0029363.jpg', '/content/HAM10000_images_part_1/ISIC_0029364.jpg', '/content/HAM10000_images_part_1/ISIC_0029365.jpg', '/content/HAM10000_images_part_1/ISIC_0029366.jpg', '/content/HAM10000_images_part_1/ISIC_0029367.jpg', '/content/HAM10000_images_part_1/ISIC_0029368.jpg', '/content/HAM10000_images_part_1/ISIC_0029369.jpg', '/content/HAM10000_images_part_1/ISIC_0029370.jpg', '/content/HAM10000_images_part_1/ISIC_0029371.jpg', '/content/HAM10000_images_part_1/ISIC_0029372.jpg', '/content/HAM10000_images_part_1/ISIC_0029373.jpg', '/content/HAM10000_images_part_1/ISIC_0029374.jpg', '/content/HAM10000_images_part_1/ISIC_0029375.jpg', '/content/HAM10000_images_part_1/ISIC_0029376.jpg', '/content/HAM10000_images_part_1/ISIC_0029377.jpg', '/content/HAM10000_images_part_1/ISIC_0029378.jpg', '/content/HAM10000_images_part_1/ISIC_0029379.jpg', '/content/HAM10000_images_part_1/ISIC_0029380.jpg', '/content/HAM10000_images_part_1/ISIC_0029381.jpg', '/content/HAM10000_images_part_1 ...
# Training data shape: (5000, 128, 128, 3)
# Test data shape: (1512, 128, 128, 3)

# %%
# Check if the data is loaded correctly
if X_train.size == 0 or y_train.size == 0:
    raise ValueError("Training data or labels not loaded correctly.")
if X_test.size == 0 or y_test.size == 0:
    raise ValueError("Test data or labels not loaded correctly.")

# %%
# Convert labels to float32
y_train = np.array(y_train).astype('float32')
y_test = np.array(y_test).astype('float32')

# %%
# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(disease_categories), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9803 - loss: 0.0562 - val_accuracy: 0.7450 - val_loss: 2.7066
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9870 - loss: 0.0416 - val_accuracy: 0.7510 - val_loss: 2.9427
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9907 - loss: 0.0340 - val_accuracy: 0.7250 - val_loss: 3.0912
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9754 - loss: 0.0634 - val_accuracy: 0.7380 - val_loss: 2.9569
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9893 - loss: 0.0397 - val_accuracy: 0.7370 - val_loss: 2.7407
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9835 - loss: 0.0466 - val_accuracy: 0.7390 - val_loss: 3.0821
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9921 - loss: 0.0258 - val_accuracy: 0.7420 - val_loss: 3.3648
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9945 - loss: 0.0148 - val_accuracy: 0.7350 - val_loss: 3.8829
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9893 - loss: 0.0250 - val_accuracy: 0.7370 - val_loss: 3.3780
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9899 - loss: 0.0379 - val_accuracy: 0.7430 - val_loss: 2.9646
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9815 - loss: 0.0620 - val_accuracy: 0.7230 - val_loss: 2.8856
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9774 - loss: 0.0641 - val_accuracy: 0.7330 - val_loss: 2.9617
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9886 - loss: 0.0336 - val_accuracy: 0.7360 - val_loss: 2.7808
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9854 - loss: 0.0542 - val_accuracy: 0.7490 - val_loss: 3.2146
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9820 - loss: 0.0411 - val_accuracy: 0.7350 - val_loss: 3.3048
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9876 - loss: 0.0340 - val_accuracy: 0.7440 - val_loss: 3.8121
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9937 - loss: 0.0305 - val_accuracy: 0.7470 - val_loss: 3.6506
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9853 - loss: 0.0512 - val_accuracy: 0.7390 - val_loss: 3.7645
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9914 - loss: 0.0287 - val_accuracy: 0.7360 - val_loss: 3.3448
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9916 - loss: 0.0238 - val_accuracy: 0.7410 - val_loss: 3.1776
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9886 - loss: 0.0297 - val_accuracy: 0.7450 - val_loss: 3.1862
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9853 - loss: 0.0343 - val_accuracy: 0.7380 - val_loss: 3.2474
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9806 - loss: 0.0665 - val_accuracy: 0.7290 - val_loss: 3.4133
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9893 - loss: 0.0311 - val_accuracy: 0.7390 - val_loss: 3.3364
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9844 - loss: 0.0452 - val_accuracy: 0.7450 - val_loss: 3.1734
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9917 - loss: 0.0354 - val_accuracy: 0.7330 - val_loss: 3.7267
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9910 - loss: 0.0285 - val_accuracy: 0.7400 - val_loss: 3.5120
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9900 - loss: 0.0374 - val_accuracy: 0.7420 - val_loss: 3.4280
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9914 - loss: 0.0227 - val_accuracy: 0.7310 - val_loss: 3.6027
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9890 - loss: 0.0283 - val_accuracy: 0.7440 - val_loss: 3.5256
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9872 - loss: 0.0350 - val_accuracy: 0.7570 - val_loss: 3.1948
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9925 - loss: 0.0304 - val_accuracy: 0.7370 - val_loss: 4.0323
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9869 - loss: 0.0368 - val_accuracy: 0.7280 - val_loss: 3.5495
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9804 - loss: 0.0625 - val_accuracy: 0.7330 - val_loss: 3.3754
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9817 - loss: 0.0598 - val_accuracy: 0.7380 - val_loss: 3.5792
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9861 - loss: 0.0451 - val_accuracy: 0.7420 - val_loss: 3.2234
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9902 - loss: 0.0323 - val_accuracy: 0.7390 - val_loss: 3.6306
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9940 - loss: 0.0176 - val_accuracy: 0.7360 - val_loss: 3.6344
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9870 - loss: 0.0430 - val_accuracy: 0.7270 - val_loss: 3.7051
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9850 - loss: 0.0375 - val_accuracy: 0.7430 - val_loss: 3.7127
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9923 - loss: 0.0210 - val_accuracy: 0.7400 - val_loss: 3.6316
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9880 - loss: 0.0449 - val_accuracy: 0.7300 - val_loss: 3.5455
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9864 - loss: 0.0507 - val_accuracy: 0.7390 - val_loss: 3.6645
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9854 - loss: 0.0484 - val_accuracy: 0.7320 - val_loss: 3.5229
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9813 - loss: 0.0555 - val_accuracy: 0.7360 - val_loss: 3.6096
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9902 - loss: 0.0247 - val_accuracy: 0.7330 - val_loss: 3.6822
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9906 - loss: 0.0244 - val_accuracy: 0.7430 - val_loss: 3.3143
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9897 - loss: 0.0295 - val_accuracy: 0.7430 - val_loss: 3.4256
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9887 - loss: 0.0336 - val_accuracy: 0.7370 - val_loss: 3.5070
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9913 - loss: 0.0242 - val_accuracy: 0.7330 - val_loss: 4.0439

# %%
# Evaluate on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_accuracy}')
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6688 - loss: 6.2026
# Test accuracy: 0.6256613731384277

# %%
# Save the model
model.save('ham10000_classifier.keras')
